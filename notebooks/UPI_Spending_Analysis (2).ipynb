# %%
# Import Libraries
import pandas as pd
import numpy as np
import random
from faker import Faker
from datetime import datetime, timedelta

# For reproducible results
np.random.seed(42)
random.seed(42)

fake = Faker("en_IN")

# %%
# Define Project Settings
NUM_USERS = 1200

PERSONAS = [
    "Student",
    "Working Professional",
    "Family User",
    "Budget Conscious",
    "Frequent Traveler",
    "High Spender"
]

CITIES = [
    "Delhi",
    "Mumbai",
    "Bengaluru",
    "Noida",
    "Gurgaon",
    "Chandigarh",
    "Pune",
    "Hyderabad",
    "Ludhiana",
    "Kolkata",
    "Jaipur",
    "Ahmedabad"
]

DEVICES = ["Android", "iOS"]

BANKS = [
    "HDFC Bank",
    "ICICI Bank",
    "State Bank of India",
    "Axis Bank",
    "Kotak Mahindra Bank"
]

# %%
# Persona Distribution
PERSONA_PROBS = {
    "Student": 0.20,
    "Working Professional": 0.30,
    "Family User": 0.18,
    "Budget Conscious": 0.12,
    "Frequent Traveler": 0.10,
    "High Spender": 0.10
}

# %%
sum(PERSONA_PROBS.values())
# Out:
# 1.0

# %%
# Persona-wise Age Groups
AGE_GROUPS = {
    "Student": ["18-20", "21-24"],
    "Working Professional": ["22-24", "25-34", "35-44"],
    "Family User": ["30-39", "40-49", "50-59"],
    "Budget Conscious": ["25-34", "35-44", "45-54"],
    "Frequent Traveler": ["25-34", "35-44", "45-54"],
    "High Spender": ["30-39", "40-49", "50-59"]
}

# %%
# Generate 1,200 Users
users = []

persona_names = list(PERSONA_PROBS.keys())
persona_weights = list(PERSONA_PROBS.values())

for i in range(1, NUM_USERS + 1):

    user_id = f"U{i:04d}"

    persona = random.choices(
        persona_names,
        weights=persona_weights,
        k=1
    )[0]

    age_group = random.choice(AGE_GROUPS[persona])

    city = random.choice(CITIES)

    device = random.choices(
        DEVICES,
        weights=[0.82, 0.18],
        k=1
    )[0]

    bank = random.choice(BANKS)

    join_date = fake.date_between(
        start_date="-3y",
        end_date="-30d"
    )

    users.append([
        user_id,
        persona,
        age_group,
        city,
        device,
        bank,
        join_date
    ])

# %%
# Create DataFrame
users_df = pd.DataFrame(
    users,
    columns=[
        "User_ID",
        "User_Persona",
        "Age_Group",
        "City",
        "Device_Type",
        "Bank",
        "Join_Date"
    ]
)

users_df.head()
# Out:
#   User_ID          User_Persona Age_Group       City Device_Type  \
# 0   U0001           Family User     30-39  Ahmedabad     Android
# 1   U0002               Student     18-20     Jaipur     Android
# 2   U0003               Student     21-24      Delhi     Android
# 3   U0004  Working Professional     35-44      Delhi     Android
# 4   U0005  Working Professional     25-34    Kolkata     Android
#
#                   Bank   Join_Date
# 0           ICICI Bank  2024-08-02
# 1  Kotak Mahindra Bank  2024-04-25
# 2           ICICI Bank  2026-03-22
# 3  Kotak Mahindra Bank  2026-02-17
# 4            HDFC Bank  2023-10-04

# %%
# Check Persona Distribution
users_df["User_Persona"].value_counts()
# Out:
# User_Persona
# Working Professional    367
# Family User             234
# Student                 232
# Budget Conscious        141
# High Spender            118
# Frequent Traveler       108
# Name: count, dtype: int64

# %%
# Save users.csv
users_df.to_csv("users.csv", index=False)

print("users.csv created successfully!")
print("Total Users:", len(users_df))
# Out:
# users.csv created successfully!
# Total Users: 1200

# %%
# download users.csv
from google.colab import files

files.download("users.csv")

# %%
# Generate UPI Transactions
# Define Categories and Merchants
CATEGORY_MERCHANTS = {
    "Food & Dining": [
        "Swiggy", "Zomato", "McDonald's", "Domino's", "Local Restaurant"
    ],

    "Grocery": [
        "Blinkit", "Zepto", "BigBasket", "DMart", "Local Grocery Store"
    ],

    "Shopping": [
        "Amazon", "Flipkart", "Myntra", "Meesho", "Reliance Retail"
    ],

    "Transportation": [
        "Uber", "Ola", "Rapido", "Delhi Metro", "Local Transport"
    ],

    "Travel": [
        "IRCTC", "MakeMyTrip", "Goibibo", "IndiGo", "Air India"
    ],

    "Healthcare": [
        "Apollo Pharmacy", "PharmEasy", "Tata 1mg", "Local Hospital"
    ],

    "Entertainment": [
        "BookMyShow", "Netflix", "Spotify", "Gaming"
    ],

    "Bills & Utilities": [
        "Electricity Bill", "Water Bill", "Gas Bill", "Broadband"
    ],

    "Mobile Recharge": [
        "Jio", "Airtel", "Vi", "BSNL"
    ],

    "Education": [
        "Coursera", "Udemy", "Unacademy", "Online Course"
    ],

    "P2P Transfer": [
        "Friend Transfer", "Family Transfer", "Personal Transfer"
    ]
}

# %%
# Define Persona-wise Spending Behavior
PERSONA_CATEGORY_WEIGHTS = {

    "Student": {
        "Food & Dining": 25,
        "Grocery": 5,
        "Shopping": 10,
        "Transportation": 10,
        "Travel": 3,
        "Healthcare": 2,
        "Entertainment": 15,
        "Bills & Utilities": 5,
        "Mobile Recharge": 5,
        "Education": 10,
        "P2P Transfer": 10
    },

    "Working Professional": {
        "Food & Dining": 15,
        "Grocery": 15,
        "Shopping": 15,
        "Transportation": 10,
        "Travel": 5,
        "Healthcare": 5,
        "Entertainment": 5,
        "Bills & Utilities": 15,
        "Mobile Recharge": 3,
        "Education": 2,
        "P2P Transfer": 10
    },

    "Family User": {
        "Food & Dining": 8,
        "Grocery": 25,
        "Shopping": 12,
        "Transportation": 5,
        "Travel": 5,
        "Healthcare": 10,
        "Entertainment": 3,
        "Bills & Utilities": 15,
        "Mobile Recharge": 2,
        "Education": 5,
        "P2P Transfer": 10
    },

    "Budget Conscious": {
        "Food & Dining": 10,
        "Grocery": 20,
        "Shopping": 8,
        "Transportation": 10,
        "Travel": 3,
        "Healthcare": 5,
        "Entertainment": 3,
        "Bills & Utilities": 20,
        "Mobile Recharge": 6,
        "Education": 5,
        "P2P Transfer": 10
    },

    "Frequent Traveler": {
        "Food & Dining": 12,
        "Grocery": 8,
        "Shopping": 10,
        "Transportation": 15,
        "Travel": 25,
        "Healthcare": 3,
        "Entertainment": 5,
        "Bills & Utilities": 5,
        "Mobile Recharge": 2,
        "Education": 2,
        "P2P Transfer": 13
    },

    "High Spender": {
        "Food & Dining": 15,
        "Grocery": 8,
        "Shopping": 25,
        "Transportation": 8,
        "Travel": 15,
        "Healthcare": 3,
        "Entertainment": 10,
        "Bills & Utilities": 5,
        "Mobile Recharge": 1,
        "Education": 2,
        "P2P Transfer": 8
    }
}

# %%
# Define Transaction Amount Ranges
AMOUNT_RANGES = {
    "Food & Dining": (150, 2500),
    "Grocery": (300, 8000),
    "Shopping": (500, 25000),
    "Transportation": (50, 3000),
    "Travel": (500, 30000),
    "Healthcare": (200, 15000),
    "Entertainment": (100, 3000),
    "Bills & Utilities": (300, 10000),
    "Mobile Recharge": (100, 1500),
    "Education": (500, 20000),
    "P2P Transfer": (100, 10000)
}

# %%
# Define Transactions Per Persona
TRANSACTION_COUNT = {
    "Student": (90, 140),
    "Working Professional": (120, 180),
    "Family User": (100, 160),
    "Budget Conscious": (80, 120),
    "Frequent Traveler": (110, 170),
    "High Spender": (140, 220)
}

# %%
# Create Random Transaction Date
from datetime import datetime, timedelta
START_DATE = datetime(2025, 8, 1)
END_DATE = datetime(2026, 7, 31)

def random_date():
    days_between = (END_DATE - START_DATE).days
    random_days = random.randint(0, days_between)
    return START_DATE + timedelta(days=random_days)

# %%
# Create Realistic Time Logic
def get_time_period(hour):
    if 5 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 17:
        return "Afternoon"
    elif 17 <= hour < 22:
        return "Evening"
    else:
        return "Night"

# %%
import pandas as pd

users_df = pd.read_csv("users.csv")

print(users_df.shape)
users_df.head()
# Out:
# (1200, 7)
#   User_ID          User_Persona Age_Group       City Device_Type  \
# 0   U0001           Family User     30-39  Ahmedabad     Android
# 1   U0002               Student     18-20     Jaipur     Android
# 2   U0003               Student     21-24      Delhi     Android
# 3   U0004  Working Professional     35-44      Delhi     Android
# 4   U0005  Working Professional     25-34    Kolkata     Android
#
#                   Bank   Join_Date
# 0           ICICI Bank  2024-08-02
# 1  Kotak Mahindra Bank  2024-04-25
# 2           ICICI Bank  2026-03-22
# 3  Kotak Mahindra Bank  2026-02-17
# 4            HDFC Bank  2023-10-04

# %%
import random
import numpy as np
transactions = []

transaction_number = 1

for _, user in users_df.iterrows():

    user_id = user["User_ID"]
    persona = user["User_Persona"]

    min_txn, max_txn = TRANSACTION_COUNT[persona]
    num_transactions = random.randint(min_txn, max_txn)

    categories = list(PERSONA_CATEGORY_WEIGHTS[persona].keys())
    weights = list(PERSONA_CATEGORY_WEIGHTS[persona].values())

    for _ in range(num_transactions):

        transaction_date = random_date()

        hour = random.choices(
            range(24),
            weights=[
                1, 1, 1, 1, 1, 2,
                4, 5, 6, 7, 8, 8,
                7, 7, 8, 9, 10, 12,
                15, 15, 12, 8, 4, 2
            ],
            k=1
        )[0]

        minute = random.randint(0, 59)
        transaction_time = f"{hour:02d}:{minute:02d}:00"
        time_period = get_time_period(hour)

        day_name = transaction_date.strftime("%A")
        day_type = "Weekend" if day_name in ["Saturday", "Sunday"] else "Weekday"

        category = random.choices(
            categories,
            weights=weights,
            k=1
        )[0]

        merchant = random.choice(CATEGORY_MERCHANTS[category])

        min_amount, max_amount = AMOUNT_RANGES[category]

        amount = round(
            np.random.uniform(min_amount, max_amount),
            2
        )

        status = random.choices(
            ["Success", "Failed", "Pending"],
            weights=[94, 4, 2],
            k=1
        )[0]

        transactions.append([
            f"UPI{transaction_number:06d}",
            user_id,
            transaction_date.date(),
            transaction_time,
            category,
            merchant,
            amount,
            status,
            day_type,
            time_period,
            transaction_date.strftime("%B"),
            transaction_date.year
        ])

        transaction_number += 1

# %%
#Create Transactions DataFrame
transactions_df = pd.DataFrame(
    transactions,
    columns=[
        "Transaction_ID",
        "User_ID",
        "Transaction_Date",
        "Transaction_Time",
        "Category",
        "Merchant",
        "Amount",
        "Payment_Status",
        "Day_Type",
        "Time_Period",
        "Month",
        "Year"
    ]
)

transactions_df.head()
# Out:
#   Transaction_ID User_ID Transaction_Date Transaction_Time         Category  \
# 0      UPI000001   U0001       2026-05-19         17:01:00  Mobile Recharge
# 1      UPI000002   U0001       2026-01-21         21:30:00     P2P Transfer
# 2      UPI000003   U0001       2026-04-04         09:29:00        Education
# 3      UPI000004   U0001       2026-02-28         21:03:00  Mobile Recharge
# 4      UPI000005   U0001       2026-07-14         12:34:00    Food & Dining
#
#            Merchant    Amount Payment_Status Day_Type Time_Period     Month  \
# 0            Airtel    624.36        Success  Weekday     Evening       May
# 1   Friend Transfer   9512.07        Success  Weekday     Evening   January
# 2         Unacademy  14773.88        Success  Weekend     Morning     April
# 3                Vi    938.12        Success  Weekend     Evening  February
# 4  Local Restaurant    516.64        Success  Weekday   Afternoon      July
#
#    Year
# 0  2026
# 1  2026
# 2  2026
# 3  2026
# 4  2026

# %%
# Check Dataset Size
print("Total Transactions:", len(transactions_df))
print("Total Users:", transactions_df["User_ID"].nunique())

transactions_df.head()
# Out:
# Total Transactions: 161825
# Total Users: 1200
#   Transaction_ID User_ID Transaction_Date Transaction_Time         Category  \
# 0      UPI000001   U0001       2026-05-19         17:01:00  Mobile Recharge
# 1      UPI000002   U0001       2026-01-21         21:30:00     P2P Transfer
# 2      UPI000003   U0001       2026-04-04         09:29:00        Education
# 3      UPI000004   U0001       2026-02-28         21:03:00  Mobile Recharge
# 4      UPI000005   U0001       2026-07-14         12:34:00    Food & Dining
#
#            Merchant    Amount Payment_Status Day_Type Time_Period     Month  \
# 0            Airtel    624.36        Success  Weekday     Evening       May
# 1   Friend Transfer   9512.07        Success  Weekday     Evening   January
# 2         Unacademy  14773.88        Success  Weekend     Morning     April
# 3                Vi    938.12        Success  Weekend     Evening  February
# 4  Local Restaurant    516.64        Success  Weekday   Afternoon      July
#
#    Year
# 0  2026
# 1  2026
# 2  2026
# 3  2026
# 4  2026

# %%
# Persona-specific amount adjustment
transactions_df = transactions_df.merge(
    users_df[["User_ID", "User_Persona"]],
    on="User_ID",
    how="left"
)

# Persona-wise spending multiplier
PERSONA_AMOUNT_MULTIPLIER = {
    "Student": (0.35, 0.80),
    "Working Professional": (0.70, 1.20),
    "Family User": (0.80, 1.30),
    "Budget Conscious": (0.40, 0.85),
    "Frequent Traveler": (0.90, 1.60),
    "High Spender": (1.50, 2.50)
}

def adjust_amount(row):
    low, high = PERSONA_AMOUNT_MULTIPLIER[row["User_Persona"]]

    multiplier = np.random.uniform(low, high)

    return round(row["Amount"] * multiplier, 2)

transactions_df["Amount"] = transactions_df.apply(
    adjust_amount,
    axis=1
)

# %%
# Weekend spending pattern
weekend_categories = ["Food & Dining", "Entertainment"]

weekend_mask = (
    (transactions_df["Day_Type"] == "Weekend") &
    (transactions_df["Category"].isin(weekend_categories))
)

transactions_df.loc[weekend_mask, "Amount"] = (
    transactions_df.loc[weekend_mask, "Amount"] *
    np.random.uniform(1.10, 1.35, weekend_mask.sum())
).round(2)

# %%
# Month-end bills pattern
transactions_df["Transaction_Date"] = pd.to_datetime(
    transactions_df["Transaction_Date"]
)

bill_mask = (
    transactions_df["Category"] == "Bills & Utilities"
)

# 70% bill transactions ko month ke last 7 days mein shift karo
bill_indices = transactions_df[
    bill_mask
].sample(
    frac=0.70,
    random_state=42
).index

for idx in bill_indices:

    current_date = transactions_df.loc[idx, "Transaction_Date"]

    # Current month ka last day
    month_end = current_date + pd.offsets.MonthEnd(0)

    # Last 7 days mein random date
    days_before = random.randint(0, 6)

    new_date = month_end - pd.Timedelta(days=days_before)

    transactions_df.loc[idx, "Transaction_Date"] = new_date

# %%
# Add transaction type
transactions_df["Transaction_Type"] = np.where(
    transactions_df["Category"] == "P2P Transfer",
    "Person to Person",
    "Merchant Payment"
)

# %%
# Final column order
transactions_df = transactions_df[
    [
        "Transaction_ID",
        "User_ID",
        "User_Persona",
        "Transaction_Date",
        "Transaction_Time",
        "Category",
        "Merchant",
        "Transaction_Type",
        "Amount",
        "Payment_Status",
        "Day_Type",
        "Time_Period",
        "Month",
        "Year"
    ]
]

transactions_df.head()
# Out:
#   Transaction_ID User_ID User_Persona Transaction_Date Transaction_Time  \
# 0      UPI000001   U0001  Family User       2026-05-19         17:01:00
# 1      UPI000002   U0001  Family User       2026-01-21         21:30:00
# 2      UPI000003   U0001  Family User       2026-04-04         09:29:00
# 3      UPI000004   U0001  Family User       2026-02-28         21:03:00
# 4      UPI000005   U0001  Family User       2026-07-14         12:34:00
#
#           Category          Merchant  Transaction_Type    Amount  \
# 0  Mobile Recharge            Airtel  Merchant Payment    808.42
# 1     P2P Transfer   Friend Transfer  Person to Person   9311.19
# 2        Education         Unacademy  Merchant Payment  12671.96
# 3  Mobile Recharge                Vi  Merchant Payment   1096.22
# 4    Food & Dining  Local Restaurant  Merchant Payment    627.43
#
#   Payment_Status Day_Type Time_Period     Month  Year
# 0        Success  Weekday     Evening       May  2026
# 1        Success  Weekday     Evening   January  2026
# 2        Success  Weekend     Morning     April  2026
# 3        Success  Weekend     Evening  February  2026
# 4        Success  Weekday   Afternoon      July  2026

# %%
# Dataset validation
print("Total Transactions:", len(transactions_df))
print("Total Users:", transactions_df["User_ID"].nunique())

print("\nTransactions per User:")
print(
    transactions_df.groupby("User_ID")
    .size()
    .describe()
)

print("\nPersona-wise Average Transaction Amount:")
print(
    transactions_df.groupby("User_Persona")["Amount"]
    .mean()
    .sort_values()
)

print("\nDate Range:")
print(
    transactions_df["Transaction_Date"].min(),
    "to",
    transactions_df["Transaction_Date"].max()
)

print("\nMissing Values:")
print(transactions_df.isnull().sum())
# Out:
# Total Transactions: 161825
# Total Users: 1200
#
# Transactions per User:
# count    1200.000000
# mean      134.854167
# std        27.774402
# min        81.000000
# 25%       114.000000
# 50%       133.000000
# 75%       153.000000
# max       220.000000
# dtype: float64
#
# Persona-wise Average Transaction Amount:
# User_Persona
# Student                  2710.580758
# Budget Conscious         3203.555309
# Working Professional     5355.141962
# Family User              6432.978895
# Frequent Traveler        9001.738879
# High Spender            14879.411595
# Name: Amount, dtype: float64
#
# Date Range:
# 2025-08-01 00:00:00 to 2026-07-31 00:00:00
#
# Missing Values:
# Transaction_ID      0
# User_ID             0
# User_Persona        0
# Transaction_Date    0
# Transaction_Time    0
# Category            0
# Merchant            0
# Transaction_Type    0
# Amount              0
# Payment_Status      0
# Day_Type            0
# Time_Period         0
# Month               0
# Year                0
# dtype: int64

# %%
transactions_df.to_csv(
    "upi_transactions_final.csv",
    index=False
)

print("Final dataset created successfully!")
# Out:
# Final dataset created successfully!

# %%
from google.colab import files

files.download("upi_transactions_final.csv")

# %% [markdown]
# # **[Data Cleaning & Exploratory Data Analysis](https://)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
transactions = pd.read_csv("upi_transactions_final.csv")

transactions.head()
# Out:
#   Transaction_ID User_ID User_Persona Transaction_Date Transaction_Time  \
# 0      UPI000001   U0001  Family User       2026-05-19         17:01:00
# 1      UPI000002   U0001  Family User       2026-01-21         21:30:00
# 2      UPI000003   U0001  Family User       2026-04-04         09:29:00
# 3      UPI000004   U0001  Family User       2026-02-28         21:03:00
# 4      UPI000005   U0001  Family User       2026-07-14         12:34:00
#
#           Category          Merchant  Transaction_Type    Amount  \
# 0  Mobile Recharge            Airtel  Merchant Payment    808.42
# 1     P2P Transfer   Friend Transfer  Person to Person   9311.19
# 2        Education         Unacademy  Merchant Payment  12671.96
# 3  Mobile Recharge                Vi  Merchant Payment   1096.22
# 4    Food & Dining  Local Restaurant  Merchant Payment    627.43
#
#   Payment_Status Day_Type Time_Period     Month  Year
# 0        Success  Weekday     Evening       May  2026
# 1        Success  Weekday     Evening   January  2026
# 2        Success  Weekend     Morning     April  2026
# 3        Success  Weekend     Evening  February  2026
# 4        Success  Weekday   Afternoon      July  2026

# %%
# Dataset Overview
print("Dataset Shape:", transactions.shape)

print("\nColumn Names:")
print(transactions.columns.tolist())

print("\nData Types:")
print(transactions.dtypes)
# Out:
# Dataset Shape: (161825, 14)
#
# Column Names:
# ['Transaction_ID', 'User_ID', 'User_Persona', 'Transaction_Date', 'Transaction_Time', 'Category', 'Merchant', 'Transaction_Type', 'Amount', 'Payment_Status', 'Day_Type', 'Time_Period', 'Month', 'Year']
#
# Data Types:
# Transaction_ID       object
# User_ID              object
# User_Persona         object
# Transaction_Date     object
# Transaction_Time     object
# Category             object
# Merchant             object
# Transaction_Type     object
# Amount              float64
# Payment_Status       object
# Day_Type             object
# Time_Period          object
# Month                object
# Year                  int64
# dtype: object

# %%
# Missing Values Check
print("Missing Values:")
print(transactions.isnull().sum())
# Out:
# Missing Values:
# Transaction_ID      0
# User_ID             0
# User_Persona        0
# Transaction_Date    0
# Transaction_Time    0
# Category            0
# Merchant            0
# Transaction_Type    0
# Amount              0
# Payment_Status      0
# Day_Type            0
# Time_Period         0
# Month               0
# Year                0
# dtype: int64

# %%
# Duplicate Check
print("Duplicate Rows:", transactions.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
# converting data column into proper date-time-format
transactions["Transaction_Date"] = pd.to_datetime(
    transactions["Transaction_Date"]
)

transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161825 entries, 0 to 161824
# Data columns (total 14 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction_ID    161825 non-null  object
#  1   User_ID           161825 non-null  object
#  2   User_Persona      161825 non-null  object
#  3   Transaction_Date  161825 non-null  datetime64[ns]
#  4   Transaction_Time  161825 non-null  object
#  5   Category          161825 non-null  object
#  6   Merchant          161825 non-null  object
#  7   Transaction_Type  161825 non-null  object
#  8   Amount            161825 non-null  float64
#  9   Payment_Status    161825 non-null  object
#  10  Day_Type          161825 non-null  object
#  11  Time_Period       161825 non-null  object
#  12  Month             161825 non-null  object
#  13  Year              161825 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(11)
# memory usage: 17.3+ MB

# %%
# Data Validation Checks
print("Minimum Transaction Amount:", transactions["Amount"].min())
print("Maximum Transaction Amount:", transactions["Amount"].max())

print("\nPayment Status:")
print(transactions["Payment_Status"].value_counts())

print("\nTransaction Type:")
print(transactions["Transaction_Type"].value_counts())

print("\nCategories:")
print(transactions["Category"].value_counts())

print(
    "Negative Amount Transactions:",
    (transactions["Amount"] <= 0).sum()
)
# Out:
# Minimum Transaction Amount: 18.68
# Maximum Transaction Amount: 73857.26
#
# Payment Status:
# Payment_Status
# Success    152149
# Failed       6447
# Pending      3229
# Name: count, dtype: int64
#
# Transaction Type:
# Transaction_Type
# Merchant Payment    145680
# Person to Person     16145
# Name: count, dtype: int64
#
# Categories:
# Category
# Food & Dining        23797
# Grocery              22730
# Shopping             22351
# Bills & Utilities    18752
# P2P Transfer         16145
# Transportation       14890
# Travel               12463
# Entertainment        10781
# Healthcare            8221
# Education             6744
# Mobile Recharge       4951
# Name: count, dtype: int64
# Negative Amount Transactions: 0

# %%
# Creating Clean DataFrame
transactions_clean = transactions.copy()

transactions_clean["Amount"] = (
    transactions_clean["Amount"].round(2)
)

transactions_clean = transactions_clean.drop_duplicates()

print("Final Clean Dataset Shape:", transactions_clean.shape)
# Out:
# Final Clean Dataset Shape: (161825, 14)

# %%
# Save cleaned dataset
transactions_clean.to_csv(
    "upi_transactions_clean.csv",
    index=False
)

print("Clean dataset saved successfully!")
# Out:
# Clean dataset saved successfully!

# %% [markdown]
# ## ANALYSIS 1

# %%
# Overall KPIs
total_transactions = len(transactions_clean)

total_users = transactions_clean["User_ID"].nunique()

total_spend = transactions_clean.loc[
    transactions_clean["Payment_Status"] == "Success",
    "Amount"
].sum()

avg_transaction = transactions_clean.loc[
    transactions_clean["Payment_Status"] == "Success",
    "Amount"
].mean()

print(f"Total Transactions: {total_transactions:,}")
print(f"Total Users: {total_users:,}")
print(f"Total Successful Spend: ₹{total_spend:,.2f}")
print(f"Average Transaction Value: ₹{avg_transaction:,.2f}")
# Out:
# Total Transactions: 161,825
# Total Users: 1,200
# Total Successful Spend: ₹993,139,552.98
# Average Transaction Value: ₹6,527.41

# %% [markdown]
# ## ANALYSIS 2

# %%
# Category-wise Spending
successful_txn = transactions_clean[
    transactions_clean["Payment_Status"] == "Success"
].copy()

category_spend = (
    successful_txn.groupby("Category")["Amount"]
    .agg(
        Total_Spend="sum",
        Avg_Transaction="mean",
        Transaction_Count="count"
    )
    .sort_values("Total_Spend", ascending=False)
)

category_spend
# Out:
#                     Total_Spend  Avg_Transaction  Transaction_Count
# Category
# Shopping           3.151474e+08     14946.520503              21085
# Travel             2.300491e+08     19650.556235              11707
# Grocery            9.021285e+07      4223.645835              21359
# Bills & Utilities  8.826569e+07      4992.403285              17680
# P2P Transfer       7.845155e+07      5172.516171              15167
# Healthcare         6.038964e+07      7846.886302               7696
# Education          5.680526e+07      8982.489703               6324
# Food & Dining      3.139007e+07      1403.159096              22371
# Transportation     2.217524e+07      1584.737934              13993
# Entertainment      1.705185e+07      1682.139399              10137
# Mobile Recharge    3.200953e+06       691.350564               4630

# %% [markdown]
# ## ANALYSIS 3

# %%
# Persona-wise Spending
persona_spend = (
    successful_txn.groupby("User_Persona")
    .agg(
        Total_Spend=("Amount", "sum"),
        Avg_Transaction=("Amount", "mean"),
        Transactions=("Transaction_ID", "count"),
        Unique_Users=("User_ID", "nunique")
    )
    .sort_values("Total_Spend", ascending=False)
)

persona_spend
# Out:
#                        Total_Spend  Avg_Transaction  Transactions  \
# User_Persona
# High Spender          2.959480e+08     14912.975060         19845
# Working Professional  2.748250e+08      5352.933963         51341
# Family User           1.822066e+08      6435.893873         28311
# Frequent Traveler     1.299850e+08      9001.108963         14441
# Student               6.801500e+07      2712.246461         25077
# Budget Conscious      4.215997e+07      3209.987045         13134
#
#                       Unique_Users
# User_Persona
# High Spender                   118
# Working Professional           367
# Family User                    234
# Frequent Traveler              108
# Student                        232
# Budget Conscious               141

# %% [markdown]
# ## ANALYSIS 4

# %%
# Monthly Spending Trend
monthly_spend = (
    successful_txn.groupby(
        successful_txn["Transaction_Date"].dt.to_period("M")
    )["Amount"]
    .sum()
)

monthly_spend
# Out:
# Transaction_Date
# 2025-08    83143524.53
# 2025-09    81169463.00
# 2025-10    83442102.68
# 2025-11    81131067.35
# 2025-12    84659325.33
# 2026-01    83294931.25
# 2026-02    77978813.03
# 2026-03    86338104.14
# 2026-04    82285886.85
# 2026-05    83826486.41
# 2026-06    81897864.22
# 2026-07    83971984.19
# Freq: M, Name: Amount, dtype: float64

# %%
# Visualization setup
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import numpy as np

# Professional color palette
COLORS = {
    "primary": "#4F46E5",      # Indigo
    "secondary": "#14B8A6",    # Teal
    "accent": "#F59E0B",       # Amber
    "danger": "#EF4444",       # Red
    "dark": "#1F2937",         # Dark Gray
    "light": "#E5E7EB"         # Light Gray
}

plt.rcParams["figure.figsize"] = (12, 6)
plt.rcParams["axes.titlesize"] = 15
plt.rcParams["axes.labelsize"] = 11

# %% [markdown]
# # **Visualization 1 - Category-wise Spending Analysis**

# %%
category_plot = category_spend.sort_values(
    "Total_Spend",
    ascending=True
)

plt.figure(figsize=(11, 6))

bars = plt.barh(
    category_plot.index,
    category_plot["Total_Spend"],
    color=COLORS["primary"]
)

plt.title(
    "UPI Spending Distribution by Category",
    fontweight="bold",
    color=COLORS["dark"],
    pad=15
)

plt.xlabel("Total Successful Spend (₹)")
plt.ylabel("Transaction Category")

# Add value labels
for bar in bars:
    value = bar.get_width()

    plt.text(
        value,
        bar.get_y() + bar.get_height()/2,
        f" ₹{value/100000:.2f}L",
        va="center",
        fontsize=9
    )

plt.gca().xaxis.set_major_formatter(
    mtick.FuncFormatter(lambda x, pos: f"₹{x/100000:.1f}L")
)

plt.grid(axis="x", alpha=0.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHT:
# # This visualization identifies the categories contributing the highest transaction value. Categories with high total spend can be important for personalized budgeting recommendations and customer segmentation.

# %% [markdown]
# # **Visualization 2 - Monthly UPI Spending Trend**

# %%
monthly_plot = (
    successful_txn
    .groupby(successful_txn["Transaction_Date"].dt.to_period("M"))["Amount"]
    .sum()
)

monthly_plot.index = monthly_plot.index.astype(str)

plt.figure(figsize=(12, 6))

plt.plot(
    monthly_plot.index,
    monthly_plot.values,
    marker="o",
    linewidth=3,
    markersize=7,
    color=COLORS["secondary"]
)

# Highlight highest spending month
max_month = monthly_plot.idxmax()
max_value = monthly_plot.max()

plt.scatter(
    max_month,
    max_value,
    s=120,
    color=COLORS["accent"],
    zorder=3,
    label=f"Peak: {max_month}"
)

plt.annotate(
    f"₹{max_value/100000:.2f}L",
    xy=(max_month, max_value),
    xytext=(0, 15),
    textcoords="offset points",
    ha="center",
    fontweight="bold"
)

plt.title(
    "Monthly UPI Spending Trend",
    fontweight="bold",
    color=COLORS["dark"],
    pad=15
)

plt.xlabel("Month")
plt.ylabel("Total Successful Spend (₹)")

plt.xticks(rotation=45)

plt.gca().yaxis.set_major_formatter(
    mtick.FuncFormatter(lambda x, pos: f"₹{x/100000:.1f}L")
)

plt.grid(alpha=0.25)
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHT:
# # The monthly trend helps identify periods of increased or decreased consumer spending. The highlighted peak month can be investigated further by category, user persona, and transaction behavior.

# %% [markdown]
# # **Visualization 3 - Persona-wise Average Transaction Value**

# %%
persona_avg = (
    successful_txn
    .groupby("User_Persona")["Amount"]
    .mean()
    .sort_values()
)

plt.figure(figsize=(10, 6))

bars = plt.bar(
    persona_avg.index,
    persona_avg.values,
    color=[
        COLORS["primary"],
        "#6366F1",
        "#8B5CF6",
        "#0EA5E9",
        COLORS["secondary"],
        COLORS["accent"]
    ]
)

plt.title(
    "Average Transaction Value by User Persona",
    fontweight="bold",
    color=COLORS["dark"],
    pad=15
)

plt.xlabel("User Persona")
plt.ylabel("Average Transaction Value (₹)")

plt.xticks(rotation=25, ha="right")

for bar in bars:
    height = bar.get_height()

    plt.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f"₹{height:,.0f}",
        ha="center",
        va="bottom",
        fontsize=9,
        fontweight="bold"
    )

plt.gca().yaxis.set_major_formatter(
    mtick.FuncFormatter(lambda x, pos: f"₹{x:,.0f}")
)

plt.grid(axis="y", alpha=0.2)

plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHT:
# # User personas demonstrate clearly different spending behaviors. This validates the persona-based synthetic data generation approach and provides a foundation for personalized financial insights and user-level anomaly detection.

# %% [markdown]
# # **Visualization 4 - Weekend vs Weekday Spending**

# %%
daytype_spend = (
    successful_txn
    .groupby("Day_Type")["Amount"]
    .agg(["sum", "mean", "count"])
)

# Proper order
daytype_spend = daytype_spend.reindex(
    ["Weekday", "Weekend"]
)

plt.figure(figsize=(9, 6))

bars = plt.bar(
    daytype_spend.index,
    daytype_spend["mean"],
    color=[COLORS["primary"], COLORS["accent"]],
    width=0.55
)

plt.title(
    "Average Transaction Value: Weekday vs Weekend",
    fontweight="bold",
    color=COLORS["dark"],
    pad=15
)

plt.xlabel("Day Type")
plt.ylabel("Average Transaction Value (₹)")

for bar in bars:
    height = bar.get_height()

    plt.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f"₹{height:,.0f}",
        ha="center",
        va="bottom",
        fontsize=11,
        fontweight="bold"
    )

plt.grid(axis="y", alpha=0.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHT:
# # Comparing weekday and weekend transaction values helps identify behavioral changes in consumer spending. A higher weekend average may indicate increased discretionary spending on categories such as dining, entertainment, and shopping.

# %% [markdown]
# # **Visualization 5 - Spending by Time Period**

# %%
time_order = [
    "Morning",
    "Afternoon",
    "Evening",
    "Night"
]

time_spend = (
    successful_txn
    .groupby("Time_Period")["Amount"]
    .agg(["sum", "mean", "count"])
    .reindex(time_order)
)

plt.figure(figsize=(10, 6))

bars = plt.bar(
    time_spend.index,
    time_spend["count"],
    color=[
        "#38BDF8",
        COLORS["secondary"],
        COLORS["primary"],
        COLORS["dark"]
    ]
)

plt.title(
    "UPI Transaction Frequency by Time of Day",
    fontweight="bold",
    color=COLORS["dark"],
    pad=15
)

plt.xlabel("Time Period")
plt.ylabel("Number of Successful Transactions")

for bar in bars:
    height = bar.get_height()

    plt.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f"{height:,.0f}",
        ha="center",
        va="bottom",
        fontsize=10,
        fontweight="bold"
    )

plt.grid(axis="y", alpha=0.2)

plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHT:
# # Transaction frequency varies across different times of the day. Time-based behavior can later be combined with transaction amount to identify unusual patterns, such as high-value late-night activity.

# %% [markdown]
# # **Visualization 6 - Transaction Volume vs Total Spend by Category**

# %%
category_metrics = (
    successful_txn
    .groupby("Category")
    .agg(
        Transaction_Count=("Transaction_ID", "count"),
        Total_Spend=("Amount", "sum"),
        Avg_Transaction=("Amount", "mean")
    )
)

plt.figure(figsize=(10, 7))

scatter = plt.scatter(
    category_metrics["Transaction_Count"],
    category_metrics["Total_Spend"],
    s=category_metrics["Avg_Transaction"] / 10,
    alpha=0.75,
    color=COLORS["primary"]
)

# Add category labels
for category, row in category_metrics.iterrows():
    plt.annotate(
        category,
        (
            row["Transaction_Count"],
            row["Total_Spend"]
        ),
        xytext=(5, 5),
        textcoords="offset points",
        fontsize=8
    )

plt.title(
    "Category Spending: Transaction Volume vs Total Spend",
    fontweight="bold",
    color=COLORS["dark"],
    pad=15
)

plt.xlabel("Transaction Count")
plt.ylabel("Total Spend (₹)")

plt.gca().yaxis.set_major_formatter(
    mtick.FuncFormatter(lambda x, pos: f"₹{x/100000:.1f}L")
)

plt.grid(alpha=0.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHT:
# # This analysis differentiates high-frequency categories from high-value categories. Categories appearing higher on the chart contribute more to overall spending, while larger bubbles represent categories with higher average transaction values.

# %% [markdown]
# # **Visualization 7 - Top 10 Merchants by Total Spend**

# %%
top_merchants = (
    successful_txn
    .groupby("Merchant")["Amount"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .sort_values()
)

plt.figure(figsize=(11, 6))

bars = plt.barh(
    top_merchants.index,
    top_merchants.values,
    color=COLORS["secondary"]
)

plt.title(
    "Top 10 Merchants by UPI Transaction Value",
    fontweight="bold",
    color=COLORS["dark"],
    pad=15
)

plt.xlabel("Total Successful Spend (₹)")
plt.ylabel("Merchant")

for bar in bars:
    value = bar.get_width()

    plt.text(
        value,
        bar.get_y() + bar.get_height()/2,
        f"₹{value/100000:.2f}L",
        va="center",
        fontsize=9
    )

plt.gca().xaxis.set_major_formatter(
    mtick.FuncFormatter(lambda x, pos: f"₹{x/100000:.1f}L")
)

plt.grid(axis="x", alpha=0.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHT:
# # The top merchant analysis identifies where users concentrate their spending. High-performing merchants can be important for partnership, cashback, reward, or personalized offer strategies.

# %% [markdown]
# # **Visualization 8 - Monthly Spend by User Persona**

# %%
persona_monthly = successful_txn.copy()

persona_monthly["Month_Year"] = (
    persona_monthly["Transaction_Date"]
    .dt.to_period("M")
    .astype(str)
)

persona_monthly_summary = (
    persona_monthly
    .groupby(["Month_Year", "User_Persona"])["Amount"]
    .sum()
    .unstack()
)

plt.figure(figsize=(13, 7))

for persona in persona_monthly_summary.columns:

    plt.plot(
        persona_monthly_summary.index,
        persona_monthly_summary[persona],
        marker="o",
        linewidth=2,
        label=persona
    )

plt.title(
    "Monthly Spending Trend by User Persona",
    fontweight="bold",
    color=COLORS["dark"],
    pad=15
)

plt.xlabel("Month")
plt.ylabel("Total Spend (₹)")

plt.xticks(rotation=45)

plt.gca().yaxis.set_major_formatter(
    mtick.FuncFormatter(lambda x, pos: f"₹{x/100000:.1f}L")
)

plt.legend(
    title="User Persona",
    bbox_to_anchor=(1.02, 1),
    loc="upper left"
)

plt.grid(alpha=0.2)

plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHT:
# # Persona-level monthly trends reveal how different user segments contribute to spending over time. This segmentation can support targeted financial products, personalized recommendations, and more accurate user-level anomaly detection.

# %% [markdown]
# ## **Anomaly Detection & Spending Risk Analysis**
#
# # This section identifies unusual UPI transactions by comparing each transaction with the user's historical spending behavior, category-level patterns, transaction timing, and daily spending patterns. The objective is to create an interpretable risk score rather than relying only on a black-box anomaly detection model.

# %%
# Create a separate dataset for anomaly analysis
anomaly_df = successful_txn.copy()

print("Transactions used for anomaly analysis:", anomaly_df.shape)
anomaly_df.head()
# Out:
# Transactions used for anomaly analysis: (152149, 14)
#   Transaction_ID User_ID User_Persona Transaction_Date Transaction_Time  \
# 0      UPI000001   U0001  Family User       2026-05-19         17:01:00
# 1      UPI000002   U0001  Family User       2026-01-21         21:30:00
# 2      UPI000003   U0001  Family User       2026-04-04         09:29:00
# 3      UPI000004   U0001  Family User       2026-02-28         21:03:00
# 4      UPI000005   U0001  Family User       2026-07-14         12:34:00
#
#           Category          Merchant  Transaction_Type    Amount  \
# 0  Mobile Recharge            Airtel  Merchant Payment    808.42
# 1     P2P Transfer   Friend Transfer  Person to Person   9311.19
# 2        Education         Unacademy  Merchant Payment  12671.96
# 3  Mobile Recharge                Vi  Merchant Payment   1096.22
# 4    Food & Dining  Local Restaurant  Merchant Payment    627.43
#
#   Payment_Status Day_Type Time_Period     Month  Year
# 0        Success  Weekday     Evening       May  2026
# 1        Success  Weekday     Evening   January  2026
# 2        Success  Weekend     Morning     April  2026
# 3        Success  Weekend     Evening  February  2026
# 4        Success  Weekday   Afternoon      July  2026

# %%
# User-level spending baseline
user_stats = (
    anomaly_df
    .groupby("User_ID")["Amount"]
    .agg(
        User_Avg_Spend="mean",
        User_Median_Spend="median",
        User_Std_Spend="std",
        User_Min_Spend="min",
        User_Max_Spend="max",
        User_Transaction_Count="count"
    )
    .reset_index()
)

user_stats.head()
# Out:
#   User_ID  User_Avg_Spend  User_Median_Spend  User_Std_Spend  User_Min_Spend  \
# 0   U0001     5711.231102           3455.895     6029.471626          132.64
# 1   U0002     2138.409375           1032.995     2901.481824           65.58
# 2   U0003     3075.481758           1607.520     3622.473574           74.98
# 3   U0004     5727.928983           3728.000     5608.709924           97.74
# 4   U0005     5615.506644           2639.735     6250.028582          127.92
#
#    User_Max_Spend  User_Transaction_Count
# 0        30268.72                     118
# 1        18616.04                      96
# 2        18359.02                      91
# 3        26854.93                     118
# 4        32544.61                     146

# %%
anomaly_df = anomaly_df.merge(
    user_stats,
    on="User_ID",
    how="left"
)

anomaly_df.head()
# Out:
#   Transaction_ID User_ID User_Persona Transaction_Date Transaction_Time  \
# 0      UPI000001   U0001  Family User       2026-05-19         17:01:00
# 1      UPI000002   U0001  Family User       2026-01-21         21:30:00
# 2      UPI000003   U0001  Family User       2026-04-04         09:29:00
# 3      UPI000004   U0001  Family User       2026-02-28         21:03:00
# 4      UPI000005   U0001  Family User       2026-07-14         12:34:00
#
#           Category          Merchant  Transaction_Type    Amount  \
# 0  Mobile Recharge            Airtel  Merchant Payment    808.42
# 1     P2P Transfer   Friend Transfer  Person to Person   9311.19
# 2        Education         Unacademy  Merchant Payment  12671.96
# 3  Mobile Recharge                Vi  Merchant Payment   1096.22
# 4    Food & Dining  Local Restaurant  Merchant Payment    627.43
#
#   Payment_Status Day_Type Time_Period     Month  Year  User_Avg_Spend  \
# 0        Success  Weekday     Evening       May  2026     5711.231102
# 1        Success  Weekday     Evening   January  2026     5711.231102
# 2        Success  Weekend     Morning     April  2026     5711.231102
# 3        Success  Weekend     Evening  February  2026     5711.231102
# 4        Success  Weekday   Afternoon      July  2026     5711.231102
#
#    User_Median_Spend  User_Std_Spend  User_Min_Spend  User_Max_Spend  \
# 0           3455.895     6029.471626          132.64        30268.72
# 1           3455.895     6029.471626          132.64        30268.72
# 2           3455.895     6029.471626          132.64        30268.72
# 3           3455.895     6029.471626          132.64        30268.72
# 4           3455.895     6029.471626          132.64        30268.72
#
#    User_Transaction_Count
# 0                     118
# 1                     118
# 2                     118
# 3                     118
# 4                     118

# %%
# Amount deviation analysis
anomaly_df["Amount_Ratio_to_Avg"] = (
    anomaly_df["Amount"] /
    anomaly_df["User_Avg_Spend"]
)

anomaly_df["Amount_Deviation"] = (
    anomaly_df["Amount"] -
    anomaly_df["User_Avg_Spend"]
)

anomaly_df[
    [
        "User_ID",
        "Amount",
        "User_Avg_Spend",
        "Amount_Ratio_to_Avg",
        "Amount_Deviation"
    ]
].head()
# Out:
#   User_ID    Amount  User_Avg_Spend  Amount_Ratio_to_Avg  Amount_Deviation
# 0   U0001    808.42     5711.231102             0.141549      -4902.811102
# 1   U0001   9311.19     5711.231102             1.630330       3599.958898
# 2   U0001  12671.96     5711.231102             2.218779       6960.728898
# 3   U0001   1096.22     5711.231102             0.191941      -4615.011102
# 4   U0001    627.43     5711.231102             0.109859      -5083.801102

# %%
# Detect unusual transaction amounts
anomaly_df["Is_Unusual_Amount"] = np.where(
    (
        anomaly_df["Amount"] >
        anomaly_df["User_Avg_Spend"] +
        (2 * anomaly_df["User_Std_Spend"].fillna(0))
    )
    &
    (
        anomaly_df["Amount"] >
        anomaly_df["User_Median_Spend"] * 2
    ),
    1,
    0
)

# %%
print(
    anomaly_df["Is_Unusual_Amount"]
    .value_counts()
)
# Out:
# Is_Unusual_Amount
# 0    142679
# 1      9470
# Name: count, dtype: int64

# %%
# Category-level anomaly
user_category_stats = (
    anomaly_df
    .groupby(["User_ID", "Category"])["Amount"]
    .agg(
        Category_Avg_Spend="mean",
        Category_Median_Spend="median",
        Category_Std_Spend="std",
        Category_Transaction_Count="count"
    )
    .reset_index()
)

# %%
anomaly_df = anomaly_df.merge(
    user_category_stats,
    on=["User_ID", "Category"],
    how="left"
)

# %%
anomaly_df["Is_Category_Anomaly"] = np.where(
    (
        anomaly_df["Category_Transaction_Count"] >= 5
    )
    &
    (
        anomaly_df["Amount"] >
        anomaly_df["Category_Avg_Spend"] +
        (2 * anomaly_df["Category_Std_Spend"].fillna(0))
    )
    &
    (
        anomaly_df["Amount"] >
        anomaly_df["Category_Median_Spend"] * 2
    ),
    1,
    0
)

# %%
# Late-night high-value transactions
anomaly_df["Is_Late_Night_High_Value"] = np.where(
    (
        anomaly_df["Time_Period"] == "Night"
    )
    &
    (
        anomaly_df["Amount"] >
        anomaly_df["User_Avg_Spend"] * 2
    ),
    1,
    0
)

# %%
# Daily spending spike
daily_spend = (
    anomaly_df
    .groupby(
        ["User_ID", "Transaction_Date"]
    )["Amount"]
    .sum()
    .reset_index(
        name="Daily_Total_Spend"
    )
)

daily_spend.head()
# Out:
#   User_ID Transaction_Date  Daily_Total_Spend
# 0   U0001       2025-08-06             834.10
# 1   U0001       2025-08-09            2548.60
# 2   U0001       2025-08-10            1834.64
# 3   U0001       2025-08-15             417.78
# 4   U0001       2025-08-16           14487.61

# %%
user_daily_baseline = (
    daily_spend
    .groupby("User_ID")["Daily_Total_Spend"]
    .agg(
        User_Avg_Daily_Spend="mean",
        User_Median_Daily_Spend="median",
        User_Daily_Std_Spend="std"
    )
    .reset_index()
)

# %%
daily_spend = daily_spend.merge(
    user_daily_baseline,
    on="User_ID",
    how="left"
)

# %%
# Detect Daily Spike
daily_spend["Is_Daily_Spending_Spike"] = np.where(
    daily_spend["Daily_Total_Spend"] >
    (
        daily_spend["User_Avg_Daily_Spend"] +
        2 * daily_spend["User_Daily_Std_Spend"].fillna(0)
    ),
    1,
    0
)

# %%
anomaly_df = anomaly_df.merge(
    daily_spend[
        [
            "User_ID",
            "Transaction_Date",
            "Daily_Total_Spend",
            "User_Avg_Daily_Spend",
            "Is_Daily_Spending_Spike"
        ]
    ],
    on=["User_ID", "Transaction_Date"],
    how="left"
)

# %%
# Create Explainable Anomaly Score
anomaly_df["Anomaly_Score"] = (
    anomaly_df["Is_Unusual_Amount"] * 40
    +
    anomaly_df["Is_Category_Anomaly"] * 25
    +
    anomaly_df["Is_Late_Night_High_Value"] * 15
    +
    anomaly_df["Is_Daily_Spending_Spike"] * 20
)

# %%
# Create Risk Levels
def assign_risk_level(score):

    if score >= 60:
        return "High"

    elif score >= 30:
        return "Medium"

    else:
        return "Low"


anomaly_df["Risk_Level"] = anomaly_df[
    "Anomaly_Score"
].apply(assign_risk_level)

# %%
print(
    anomaly_df["Risk_Level"]
    .value_counts()
)
# Out:
# Risk_Level
# Low       142492
# High        6344
# Medium      3313
# Name: count, dtype: int64

# %%
# Create final anomaly flag
anomaly_df["Is_Anomaly"] = np.where(
    anomaly_df["Anomaly_Score"] >= 30,
    1,
    0
)

print(
    anomaly_df["Is_Anomaly"]
    .value_counts()
)
# Out:
# Is_Anomaly
# 0    142492
# 1      9657
# Name: count, dtype: int64

# %%
# Validate anomaly results
risk_summary = (
    anomaly_df
    .groupby("Risk_Level")
    .agg(
        Transactions=("Transaction_ID", "count"),
        Total_Amount=("Amount", "sum"),
        Avg_Transaction=("Amount", "mean")
    )
    .sort_values("Avg_Transaction", ascending=False)
)

risk_summary
# Out:
#             Transactions  Total_Amount  Avg_Transaction
# Risk_Level
# High                6344  1.578899e+08     24888.060024
# Medium              3313  8.113682e+07     24490.436444
# Low               142492  7.541129e+08      5292.317353

# %%
top_risky_transactions = (
    anomaly_df
    .sort_values(
        ["Anomaly_Score", "Amount"],
        ascending=[False, False]
    )
    [
        [
            "Transaction_ID",
            "User_ID",
            "User_Persona",
            "Transaction_Date",
            "Transaction_Time",
            "Category",
            "Merchant",
            "Amount",
            "User_Avg_Spend",
            "Amount_Ratio_to_Avg",
            "Daily_Total_Spend",
            "Anomaly_Score",
            "Risk_Level"
        ]
    ]
    .head(20)
)

top_risky_transactions
# Out:
#        Transaction_ID User_ID          User_Persona Transaction_Date  \
# 84502       UPI089856   U0670          High Spender       2026-04-27
# 62901       UPI066921   U0500          High Spender       2026-04-15
# 60901       UPI064779   U0485          High Spender       2025-11-16
# 109500      UPI116467   U0870          High Spender       2026-04-20
# 73971       UPI078688   U0589          High Spender       2026-07-27
# 79910       UPI084973   U0633          High Spender       2025-11-12
# 44602       UPI047435   U0356          High Spender       2025-12-31
# 92355       UPI098270   U0733          High Spender       2026-02-05
# 119853      UPI127500   U0951          High Spender       2026-01-25
# 72234       UPI076851   U0574     Frequent Traveler       2026-06-14
# 102247      UPI108773   U0813     Frequent Traveler       2025-09-10
# 19878       UPI021084   U0160  Working Professional       2025-11-17
# 75866       UPI080701   U0603  Working Professional       2025-09-08
# 22753       UPI024132   U0183           Family User       2025-10-19
# 101038      UPI107484   U0804  Working Professional       2025-10-16
# 10634       UPI011266   U0085  Working Professional       2026-06-23
# 37235       UPI039595   U0296  Working Professional       2026-01-02
# 6488        UPI006859   U0053           Family User       2025-08-05
# 29083       UPI030882   U0232  Working Professional       2026-03-07
# 130574      UPI138873   U1033  Working Professional       2026-06-09
#
#        Transaction_Time  Category         Merchant    Amount  User_Avg_Spend  \
# 84502          04:04:00    Travel            IRCTC  73767.56    14059.548626
# 62901          01:00:00    Travel          Goibibo  72468.32    15661.335737
# 60901          04:31:00    Travel           IndiGo  68685.79    16199.854817
# 109500         03:19:00    Travel        Air India  67301.59    15272.455580
# 73971          00:28:00    Travel          Goibibo  61091.06    13601.919861
# 79910          01:14:00  Shopping         Flipkart  58844.02    15216.046613
# 44602          22:25:00  Shopping  Reliance Retail  56198.75    15380.281346
# 92355          02:53:00  Shopping           Meesho  54516.06    13596.615918
# 119853         02:54:00  Shopping           Meesho  51786.71    13503.588980
# 72234          02:56:00    Travel        Air India  45689.51     8273.909565
# 102247         23:42:00  Shopping           Amazon  34744.38     9137.473768
# 19878          04:09:00    Travel          Goibibo  32904.75     5418.820696
# 75866          02:44:00    Travel       MakeMyTrip  32124.04     5615.125000
# 22753          22:53:00  Shopping           Amazon  30931.94     6212.054579
# 101038         23:51:00  Shopping           Meesho  28784.72     5180.132393
# 10634          22:11:00    Travel       MakeMyTrip  28779.50     4999.016535
# 37235          22:24:00  Shopping           Meesho  27615.08     5540.145252
# 6488           22:46:00  Shopping           Myntra  27360.13     5878.465196
# 29083          00:19:00  Shopping           Myntra  27255.50     5055.399504
# 130574         22:50:00  Shopping           Amazon  25864.20     5588.872909
#
#         Amount_Ratio_to_Avg  Daily_Total_Spend  Anomaly_Score Risk_Level
# 84502              5.246794           73767.56            100       High
# 62901              4.627212           72468.32            100       High
# 60901              4.239902           68685.79            100       High
# 109500             4.406730          123198.76            100       High
# 73971              4.491356           64199.42            100       High
# 79910              3.867234           58844.02            100       High
# 44602              3.653948           65822.14            100       High
# 92355              4.009532           54516.06            100       High
# 119853             3.835033           51786.71            100       High
# 72234              5.522119           45689.51            100       High
# 102247             3.802405           34744.38            100       High
# 19878              6.072308           32904.75            100       High
# 75866              5.720984           32124.04            100       High
# 22753              4.979341           30931.94            100       High
# 101038             5.556754           41271.02            100       High
# 10634              5.757032           28779.50            100       High
# 37235              4.984541           27615.08            100       High
# 6488               4.654298           27360.13            100       High
# 29083              5.391364           27255.50            100       High
# 130574             4.627802           25864.20            100       High

# %% [markdown]
# ## **Anomaly Visualizations**

# %% [markdown]
# ## Visualization 1 - Risk Level Distribution

# %%
risk_counts = (
    anomaly_df["Risk_Level"]
    .value_counts()
    .reindex(["Low", "Medium", "High"])
    .fillna(0)
)

plt.figure(figsize=(9, 5))

bars = plt.bar(
    risk_counts.index,
    risk_counts.values,
    color=[
        "#22C55E",  # Green
        "#F59E0B",  # Amber
        "#EF4444"   # Red
    ],
    width=0.55
)

plt.title(
    "Transaction Risk Distribution",
    fontweight="bold",
    color=COLORS["dark"],
    pad=15
)

plt.xlabel("Risk Level")
plt.ylabel("Number of Transactions")

for bar in bars:
    height = bar.get_height()

    plt.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f"{height:,.0f}",
        ha="center",
        va="bottom",
        fontweight="bold"
    )

plt.grid(axis="y", alpha=0.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHT:
# # Most transactions are expected to fall into the Low Risk category, while Medium and High Risk transactions represent behavior that significantly deviates from normal user spending patterns.

# %% [markdown]
# ## Visualization 2 - Risk Level vs Average Transaction Value

# %%
risk_amount = (
    anomaly_df
    .groupby("Risk_Level")["Amount"]
    .mean()
    .reindex(["Low", "Medium", "High"])
)

plt.figure(figsize=(9, 5))

bars = plt.bar(
    risk_amount.index,
    risk_amount.values,
    color=[
        "#22C55E",
        "#F59E0B",
        "#EF4444"
    ]
)

plt.title(
    "Average Transaction Value by Risk Level",
    fontweight="bold",
    color=COLORS["dark"],
    pad=15
)

plt.xlabel("Risk Level")
plt.ylabel("Average Transaction Amount (₹)")

for bar in bars:
    height = bar.get_height()

    plt.text(
        bar.get_x() + bar.get_width()/2,
        height,
        f"₹{height:,.0f}",
        ha="center",
        va="bottom",
        fontweight="bold"
    )

plt.gca().yaxis.set_major_formatter(
    mtick.FuncFormatter(lambda x, pos: f"₹{x:,.0f}")
)

plt.grid(axis="y", alpha=0.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHT:
# # Higher-risk transactions generally have a higher average transaction value because unusually large spending is one of the strongest contributors to the anomaly score.

# %% [markdown]
# ## Visualization 3 - Anomaly Signals Breakdown

# %%
signal_counts = pd.Series({
    "Unusual Amount":
        anomaly_df["Is_Unusual_Amount"].sum(),

    "Category Anomaly":
        anomaly_df["Is_Category_Anomaly"].sum(),

    "Late-Night High Value":
        anomaly_df["Is_Late_Night_High_Value"].sum(),

    "Daily Spending Spike":
        anomaly_df["Is_Daily_Spending_Spike"].sum()
}).sort_values()

# %%
plt.figure(figsize=(10, 6))

bars = plt.barh(
    signal_counts.index,
    signal_counts.values,
    color=[
        "#8B5CF6",
        "#0EA5E9",
        "#F59E0B",
        "#EF4444"
    ]
)

plt.title(
    "Anomaly Detection Signal Breakdown",
    fontweight="bold",
    color=COLORS["dark"],
    pad=15
)

plt.xlabel("Number of Transactions Flagged")
plt.ylabel("Risk Signal")

for bar in bars:
    width = bar.get_width()

    plt.text(
        width,
        bar.get_y() + bar.get_height()/2,
        f"{width:,.0f}",
        va="center",
        fontsize=10,
        fontweight="bold"
    )

plt.grid(axis="x", alpha=0.2)
plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHT:
# # This visualization shows which behavioral signals contribute most to unusual transaction detection. The rule-based approach makes the anomaly score interpretable and helps explain why a transaction was assigned a higher risk level.

# %% [markdown]
# ## Generate actual insights from the dataset

# %%
total_anomalies = anomaly_df["Is_Anomaly"].sum()

anomaly_rate = (
    anomaly_df["Is_Anomaly"].mean() * 100
)

high_risk_count = (
    anomaly_df["Risk_Level"] == "High"
).sum()

top_risk_category = (
    anomaly_df[anomaly_df["Is_Anomaly"] == 1]
    .groupby("Category")
    .size()
    .idxmax()
)

top_risk_persona = (
    anomaly_df[anomaly_df["Is_Anomaly"] == 1]
    .groupby("User_Persona")
    .size()
    .idxmax()
)

print("ANOMALY DETECTION INSIGHTS")
print("-" * 55)

print(
    f"1. Total unusual transactions detected: "
    f"{total_anomalies:,}"
)

print(
    f"2. Overall anomaly rate: "
    f"{anomaly_rate:.2f}%"
)

print(
    f"3. High-risk transactions identified: "
    f"{high_risk_count:,}"
)

print(
    f"4. Category with the highest anomaly volume: "
    f"{top_risk_category}"
)

print(
    f"5. User persona with the highest anomaly volume: "
    f"{top_risk_persona}"
)
# Out:
# ANOMALY DETECTION INSIGHTS
# -------------------------------------------------------
# 1. Total unusual transactions detected: 9,657
# 2. Overall anomaly rate: 6.35%
# 3. High-risk transactions identified: 6,344
# 4. Category with the highest anomaly volume: Shopping
# 5. User persona with the highest anomaly volume: Working Professional

# %%
# Save final analyzed dataset
anomaly_df.to_csv(
    "upi_transactions_analyzed.csv",
    index=False
)

print("Final analyzed dataset created successfully!")
print("Shape:", anomaly_df.shape)
# Out:
# Final analyzed dataset created successfully!
# Shape: (152149, 35)

# %%
from google.colab import files

files.download("upi_transactions_analyzed.csv")
